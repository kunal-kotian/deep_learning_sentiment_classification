# %%
import pandas as pd 
import numpy as np
import json
import re
from tqdm._tqdm_notebook import tqdm_notebook

# %% [markdown]
# # Load Data

# %% [markdown]
# The data from Yelp reviews is in the files `review.json` and `business.json`, which were downloaded from the following link (the link also contains detailed documentation on the structure and format of the dataset):
#
# https://www.yelp.com/dataset/documentation/json

# %%
PATH = '../data/'

# %%
with open(PATH+'review.json') as f:
    review_data = pd.DataFrame(json.loads(line) for line in f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-38b7ad69b369> in <module>()
#       1 with open(PATH+'review.json') as f:
# ----> 2     review_data = pd.DataFrame(json.loads(line) for line in f)
#
# ~/anaconda2/envs/nlp/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# ~/anaconda2/envs/nlp/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7435     elif isinstance(data[0], collections.Mapping):
#    7436         return _list_of_dict_to_arrays(data, columns,
# -> 7437                                        coerce_float=coerce_float, dtype=dtype)
#    7438     elif isinstance(data[0], Series):
#    7439         return _list_of_series_to_arrays(data, columns,
#
# ~/anaconda2/envs/nlp/lib/python3.6/site-packages/pandas/core/frame.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#    7549     if columns is None:
#    7550         gen = (list(x.keys()) for x in data)
# -> 7551         sort = not any(isinstance(d, OrderedDict) for d in data)
#    7552         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#    7553
#
# ~/anaconda2/envs/nlp/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    7549     if columns is None:
#    7550         gen = (list(x.keys()) for x in data)
# -> 7551         sort = not any(isinstance(d, OrderedDict) for d in data)
#    7552         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#    7553
#
# KeyboardInterrupt:

# %%
with open(PATH+'business.json') as f:
    business_data = pd.DataFrame(json.loads(line) for line in f)

# %% [markdown]
# The reviews are related to several different types of businesses - we first filter the reviews down to only those related to restaurants.

# %%
rest_biz = business_data[business_data['categories'].apply(str).str.contains('Restaurants')]

# %%
rest_biz = rest_biz.drop(columns=['stars'])

# %%
rest_biz.sort_values(by='review_count', ascending=False, inplace=True)

# %%
rest_biz.groupby(by=['state'])['review_count'].sum().sort_values(ascending=False)
# Out:
# state
# NV     949953
# AZ     837216
# ON     414411
# NC     180487
# OH     154726
# PA     143283
# QC      98978
# WI      69050
# BW      24934
# EDH     23747
# IL      22186
# SC       5981
# MLN      1101
# HLD       589
# C         168
# ELN       117
# FIF       110
# NYK       101
# WLN        87
# NY         73
# NI         58
# WA         40
# 01         24
# PKN        24
# ST         24
# ESX        11
# BY         10
# KHL         7
# RCC         7
# XGL         6
# 3           5
# HH          4
# CA          4
# WHT         4
# ABE         3
# ZET         3
# Name: review_count, dtype: int64

# %%
preprocessed_data = rest_biz.merge(review_data,how='inner')
preprocessed_data = preprocessed_data[preprocessed_data['state'].isin(['NV','AZ'])]

# %%
date_sorted = preprocessed_data.sort_values(by='date',ascending=False)
# Out:
#                                             address  \
# 625283               3930 Las Vegas Blvd S, Ste 120
# 1511598                            8000 S Priest Rd
# 1785108                          5436 S Central Ave
# 905222              790 Coronado Center Dr, Ste 125
# 85612                         3950 S Las Vegas Blvd
# 1894724                     451 N Old Litchfield Rd
# 425164              3635 Las Vegas Blvd S, Unit 100
# 2424452                  7250 S Durango Dr, Ste 160
# 2057328                            3241 E Shea Blvd
# 1492160                           3410 S Jones Blvd
# 1821075                           718 N Central Ave
# 1069057                        4225 Sky Harbor Blvd
# 2608928                            20227 N 67th Ave
# 1153105                       6509 Las Vegas Blvd S
# 1821037                           718 N Central Ave
# 943941                         4425 N Saddlebag Trl
# 1020228                     414 S Mill Ave, Ste 115
# 1477159                           1945 S Stapley Dr
# 734376                        15301 N Scottsdale Rd
# 1181637                 717 W Union Hills Dr, Ste 1
# 1047291                   3370 N Hayden Rd, Ste 120
# 42961                      953 E Sahara Ave, Ste A5
# 2245880                            2430 E Pebble Rd
# 1207563                           1960 W Germann Rd
# 328019                             301 N Gilbert Rd
# 1665240                              5695 W Bell Rd
# 581434                            4175 S Buffalo Dr
# 2215331                       1045 Whitney Ranch Dr
# 2539692                         7424 S Rainbow Blvd
# 929360                            745 W Baseline Rd
# ...                                             ...
# 1867998                                206 N 3rd St
# 110960                            2411 W Sahara Ave
# 236749                      4490 Spring Mountain Rd
# 1892791                             13959 W Bell Rd
# 2164658                         4209 N Craftsman Ct
# 1668063                         10430 S Eastern Ave
# 1223270                        1198 Sir Patrick Ave
# 89026                         3355 Las Vegas Blvd S
# 163539                          960 W University Dr
# 2178593                   1000 N Nellis Blvd, Ste I
# 1800894                        6316 N Scottsdale Rd
# 252034                     11051 N Black Canyon Hwy
# 1139772             2120 Festival Plaza Dr, Ste 160
# 610580                             344 N Gilbert Rd
# 1292452                    2879 N Green Valley Pkwy
# 2106054                 5240 W Baseline Rd, Ste 110
# 644078                            615 S College Ave
# 518102                      5288 Spring Mountain Rd
# 1558259                   7315 Arroyo Crossing Pkwy
# 308325   Hard Rock Hotel & Casino, 4455 Paradise Rd
# 12725                         3570 S Las Vegas Blvd
# 2357097                          7605 E McDowell Rd
# 24102                         3667 Las Vegas Blvd S
# 1884179                        1650 S Clearview Ave
# 1606241                    5670 Simmons St, Ste 104
# 2604773                            300 W Sahara Ave
# 1159411                         4915 W Glendale Ave
# 1511667                      5757 Wayne Newton Blvd
# 136863                        3600 S Las Vegas Blvd
# 858159                        7175 W Lake Mead Blvd
#
#                                                 attributes  \
# 625283   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1511598  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1785108  {'RestaurantsTableService': False, 'GoodForMea...
# 905222   {'Alcohol': 'beer_and_wine', 'HasTV': True, 'N...
# 85612    {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1894724  {'RestaurantsTableService': True, 'GoodForMeal...
# 425164   {'RestaurantsTableService': True, 'GoodForMeal...
# 2424452  {'RestaurantsTableService': False, 'GoodForMea...
# 2057328  {'Alcohol': 'full_bar', 'HasTV': False, 'Noise...
# 1492160  {'RestaurantsTableService': True, 'GoodForMeal...
# 1821075  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1069057  {'RestaurantsTableService': False, 'GoodForMea...
# 2608928  {'GoodForMeal': {'dessert': False, 'latenight'...
# 1153105  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1821037  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 943941   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1020228  {'BusinessParking': {'garage': True, 'street':...
# 1477159  {'RestaurantsTableService': False, 'GoodForMea...
# 734376   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1181637  {'RestaurantsTableService': False, 'GoodForMea...
# 1047291  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 42961    {'Alcohol': 'beer_and_wine', 'HasTV': False, '...
# 2245880  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1207563  {'RestaurantsTableService': True, 'GoodForMeal...
# 328019   {'Alcohol': 'none', 'HasTV': False, 'NoiseLeve...
# 1665240  {'RestaurantsTableService': True, 'GoodForMeal...
# 581434   {'RestaurantsTableService': True, 'GoodForMeal...
# 2215331  {'RestaurantsTableService': False, 'GoodForMea...
# 2539692  {'RestaurantsTableService': False, 'GoodForMea...
# 929360   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# ...                                                    ...
# 1867998  {'RestaurantsTableService': True, 'GoodForMeal...
# 110960   {'Alcohol': 'beer_and_wine', 'HasTV': False, '...
# 236749   {'RestaurantsTableService': True, 'GoodForMeal...
# 1892791  {'RestaurantsTableService': False, 'GoodForMea...
# 2164658  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1668063  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1223270  {'RestaurantsTableService': False, 'GoodForMea...
# 89026    {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 163539   {'Alcohol': 'full_bar', 'HasTV': False, 'Noise...
# 2178593  {'RestaurantsTableService': True, 'GoodForMeal...
# 1800894  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 252034   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1139772  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 610580   {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 1292452  {'RestaurantsTableService': True, 'GoodForMeal...
# 2106054  {'RestaurantsTableService': False, 'GoodForMea...
# 644078   {'Alcohol': 'beer_and_wine', 'HasTV': True, 'N...
# 518102   {'RestaurantsTableService': True, 'GoodForMeal...
# 1558259  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 308325   {'Alcohol': 'full_bar', 'HasTV': False, 'Noise...
# 12725    {'RestaurantsTableService': True, 'GoodForMeal...
# 2357097  {'RestaurantsTableService': True, 'GoodForMeal...
# 24102    {'RestaurantsTableService': True, 'GoodForMeal...
# 1884179  {'RestaurantsTableService': True, 'GoodForMeal...
# 1606241  {'RestaurantsTableService': False, 'GoodForMea...
# 2604773  {'GoodForMeal': {'dessert': False, 'latenight'...
# 1159411  {'Alcohol': 'none', 'HasTV': False, 'NoiseLeve...
# 1511667  {'RestaurantsTableService': True, 'GoodForMeal...
# 136863   {'Alcohol': 'full_bar', 'HasTV': False, 'Noise...
# 858159   {'RestaurantsTableService': False, 'GoodForMea...
#
#                     business_id  \
# 625283   lKq4Qsz13FDcAVgp49uukQ
# 1511598  8PBq-MHyLDrhkaTf72Foww
# 1785108  najluTSbgZEpCdLIbpvnxQ
# 905222   3oajqiPFhYQJsHHiVCchEQ
# 85612    Cni2l-VKG_pdospJ6xliXQ
# 1894724  IbsRfrHGK4g5OQd_KFtdkQ
# 425164   ysv6yhVYOoH9Pf7PlMyD0g
# 2424452  kE8hSuvO6eKtbRA1k541Jg
# 2057328  IQVka-wzJmN3jw2W70aCzw
# 1492160  Cy8XYYDrZ5wd3Bq-toXMsg
# 1821075  5RqU2YARBU69d9zK6h-fXg
# 1069057  89N3YfIoe50feyqS0qwMXg
# 2608928  _B-LJC1Aj50Cdxd9p9uBaA
# 1153105  rdE9gg0WB7Z8kRytIMSapg
# 1821037  5RqU2YARBU69d9zK6h-fXg
# 943941   0jAexNHRHhkQv4zNYqenBA
# 1020228  4K5NUsinIgtq-yuxdp2HdA
# 2357097  [Diners, American (Traditional), Restaurants, ...       Scottsdale
# 24102       [American (Traditional), Restaurants, Burgers]        Las Vegas
# 1884179                         [Steakhouses, Restaurants]             Mesa
# 1606241  [Caterers, Event Planning & Services, Restaura...  North Las Vegas
# 2604773  [Dim Sum, Food, Restaurants, Coffee & Tea, Chi...        Las Vegas
# 1159411                  [Breakfast & Brunch, Restaurants]         Glendale
# 1511667  [Restaurants, Burgers, American (Traditional),...        Las Vegas
# 136863   [Bars, Nightlife, Mediterranean, Restaurants, ...        Las Vegas
# 858159                 [Restaurants, Greek, Mediterranean]        Las Vegas
#
#                                                      hours  is_open  \
# 625283   {'Monday': '11:00-23:00', 'Tuesday': '11:00-23...        1
# 1511598  {'Monday': '11:00-2:00', 'Tuesday': '11:00-2:0...        1
# 1785108  {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 905222   {'Monday': '11:30-4:00', 'Tuesday': '11:30-4:0...        1
# 85612    {'Monday': '11:00-23:00', 'Tuesday': '11:00-23...        1
# 1894724  {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
# 425164   {'Monday': '8:00-2:00', 'Tuesday': '8:00-2:00'...        1
# 2424452  {'Monday': '10:30-21:00', 'Tuesday': '10:30-21...        1
# 2057328  {'Tuesday': '17:00-21:00', 'Friday': '17:00-21...        1
# 1492160  {'Monday': '17:30-2:30', 'Tuesday': '17:30-2:3...        1
# 1821075  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 1069057  {'Monday': '4:30-21:00', 'Tuesday': '4:30-21:0...        1
# 2608928                                                 {}        1
# 1153105  {'Monday': '11:00-0:00', 'Tuesday': '11:00-0:0...        1
# 1821037  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 943941   {'Monday': '20:00-2:00', 'Tuesday': '16:00-2:0...        1
# 1020228  {'Monday': '10:00-23:00', 'Tuesday': '10:00-23...        1
# 1477159  {'Monday': '9:00-0:00', 'Tuesday': '9:00-0:00'...        1
# 734376   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
# 1181637  {'Monday': '11:00-20:00', 'Tuesday': '11:00-20...        1
# 1047291  {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 42961    {'Monday': '11:00-14:30', 'Tuesday': '11:00-14...        1
# 2245880  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 1207563  {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
# 328019   {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 1665240  {'Monday': '11:00-2:00', 'Tuesday': '11:00-2:0...        1
# 581434   {'Monday': '17:00-2:00', 'Tuesday': '17:00-2:0...        1
# 2215331  {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...        1
# 2539692  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 929360   {'Tuesday': '17:00-21:00', 'Friday': '16:00-22...        1
# ...                                                    ...      ...
# 1867998  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 110960   {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 236749   {'Monday': '11:30-22:30', 'Tuesday': '11:30-22...        1
# 1892791  {'Monday': '7:00-21:00', 'Tuesday': '7:00-21:0...        0
# 2164658  {'Monday': '11:00-2:00', 'Tuesday': '11:00-2:0...        1
# 1668063  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 1223270                                                 {}        1
# 89026    {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 163539   {'Monday': '11:00-0:00', 'Tuesday': '11:00-0:0...        1
# 2178593  {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 1800894  {'Monday': '17:00-22:00', 'Tuesday': '17:00-21...        1
# 252034   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
# 1139772  {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
# 610580   {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 1292452  {'Monday': '11:00-21:30', 'Tuesday': '11:00-21...        1
# 2106054  {'Monday': '10:30-22:00', 'Tuesday': '10:30-22...        1
# 644078   {'Monday': '11:00-23:00', 'Tuesday': '11:00-23...        1
# 518102   {'Monday': '9:00-2:00', 'Tuesday': '9:00-2:00'...        1
# 1558259  {'Monday': '11:00-21:00', 'Tuesday': '11:00-21...        1
# 308325   {'Monday': '18:00-22:30', 'Tuesday': '18:00-22...        1
# 12725    {'Monday': '7:30-22:00', 'Tuesday': '7:30-22:0...        1
# 2357097  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 24102    {'Monday': '11:00-0:00', 'Tuesday': '11:00-0:0...        0
# 1884179  {'Monday': '11:00-21:30', 'Tuesday': '11:00-21...        1
# 1606241  {'Monday': '11:00-18:30', 'Tuesday': '11:00-19...        1
# 2604773  {'Monday': '0:00-0:00', 'Tuesday': '0:00-0:00'...        1
# 1159411  {'Monday': '6:00-14:30', 'Tuesday': '6:00-14:3...        1
# 1511667  {'Monday': '4:30-21:00', 'Tuesday': '4:30-21:0...        1
# 136863   {'Monday': '11:30-22:30', 'Tuesday': '11:30-22...        1
# 858159   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1
#
#           latitude   longitude                            name  \
# 625283   36.091262 -115.174247                  Slice of Vegas
# 1511598  33.344151 -111.963680                     Dos Gringos
# 1785108  33.396343 -112.073687           Maryln's Fish & Chips
# 905222   36.002946 -115.107756                        Sushi Wa
# 85612    36.094460 -115.176113                      Burger Bar
# 1894724  33.498528 -112.357869               Red's Bar & Grill
# 425164   36.113826 -115.171499                     Wahlburgers
# 2424452  36.056414 -115.278382                  Firehouse Subs
# 2057328  33.582071 -112.011458                     Michelina's
# 1492160  36.127713 -115.224648                           Hachi
# 1821075  33.456388 -112.074092                       The Grand
# 1069057  33.434190 -111.994339               Cartel Coffee Lab
# 2608928  33.670199 -112.202477                      McDonald's
# 1153105  36.070146 -115.173856       Lazy Dog Restaurant & Bar
# 1821037  33.456388 -112.074092                       The Grand
# 943941   33.501412 -111.921998                         El Hefe
# 1020228  33.425965 -111.940251               Fuzzy's Taco Shop
# 1477159  33.379381 -111.806728                  Raising Cane's
# 734376   33.625409 -111.925128              Brio Tuscan Grille
# 1181637  33.654353 -112.083580                   Chicago Gyros
# 1047291  33.486400 -111.910165  Uncle Sal's Italian Restaurant
# 42961    36.143450 -115.142780                   Lotus of Siam
# 2245880  36.028090 -115.117816                      PT's Ranch
# 1207563  33.276333 -111.875726          Oregano's Pizza Bistro
# 328019   33.355034 -111.789279                  Joe's Real BBQ
# 1665240  33.638659 -112.181806                     Old Chicago
# 581434   36.112931 -115.261375                          Hikari
# 2215331  36.080027 -115.053970             Manhattan Pizza III
# 2539692  36.053389 -115.242446                     Don Tortaco
# 929360   33.378474 -111.847631                   Beaver Choice
# ...            ...         ...                             ...
# 1867998  36.171913 -115.141276                    Freedom Beat
# 110960   36.142782 -115.174747                      Oyster Bar
# 236749   36.126455 -115.201851                      Ramen Sora
# 1892791  33.638231 -112.363262        Paradise Bakery and Cafe
# 2164658  33.496975 -111.927558                Old Town Gringos
# 1020228  yEqnapIduS1Tfv3RpUS_Dg
# 1477159  yEqnapIduS1Tfv3RpUS_Dg
# 734376   JJm5w0ueA2l2CtBkW9bgiQ
# 1181637  jCwWPMOmCYLR3vk1a1VfcQ
# 1047291  MAqGNbixA2wqjUPKCMX7cg
# 42961    IVe2z6k7K4gNf4wmpRMulw
# 2245880  R_4cr2rXzkYbqnhbGJgwXQ
# 1207563  PcvbBOCOcs6_suRDH7TSTg
# 328019   13CSqIS_QCl_NrMvCUUtbA
# 1665240  Ny0vlFSG6s8qr0hWjgUhBA
# 581434   LBAEYJq1jTak_mX7xOXLBw
# 2215331  FT0kjPtBUpBn8jxgRgVFIg
# 2539692  HZJsHshENoS8LXclcmIBCA
# 929360   cdh7gzM7qzhhTDJmPZh6jQ
# ...                         ...
# 1867998  c3js_hN3X6SXupOkK_TuTw
# 110960   82GOQIPlSzLvRphl9MzRhw
# 236749   6Q6K4v6U5i0UC1IzXmGTpw
# 1892791  I7xrt_PZduY4L_K6RnGwEg
# 2164658  TH81276lwrKCBa0Je4t7OQ
# 1668063  S1_V6ayPXa-aP4Uivz9Z7A
# 1223270  IL7s7BR8DuoOFwYYM6cZ7w
# 89026    M6Jg2VM4-dEbW2mj5BH1ew
# 163539   t9B6QihdatO0bbk8UBLKGQ
# 2178593  XoZpnsntuQ9AH1OYZBKe3w
# 1800894  -UvS8iLcgMRtCI6FtVKh4w
# 252034   xpkTOYhQsOCHlIXb2ujXtg
# 1139772  cgxiTbbkNg2BBuKfQwvXOw
# 610580   FYmGxLIB68Z6wxwnqRohXg
# 1292452  -aV7azrzW2rlAm6G4DA-cw
# 2106054  TmyzzU--aFnjlTMoU_ldjg
# 644078   t9B6QihdatO0bbk8UBLKGQ
# 518102   KdxrZutJCb9ToArv6jCE1A
# 1558259  pmbBJyrjk5WyALbEiN3MFg
# 308325   WtCUyow3GkmAl3PqOdJOAg
# 12725    uElKJDqH3DaQyqM2pe3mlw
# 2357097  MdOiPOtAeFAETVooZczURQ
# 24102    WlcnFp696thP7-iieEid7Q
# 1884179  c5DwPN8vdH-Q1wid7xDD_w
# 1606241  t16zDLvOd07Y6-9viHM2cQ
# 2604773  NMVWEnN3G2XkXrtgh3PWrg
# 1159411  K4hauQ-gDEwy6oEV_9AK0w
# 1511667  FXW16a1QddonpF-h3NtxPg
# 136863   jfZgi0Fl9rU1k_aoTw4E5Q
# 858159   62OHTL6ZocdL4hcyvW09sA
#
# [241221 rows x 22 columns]

# %%
data_20150101 = date_sorted[date_sorted['date']>'2017-01-01']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-68a2ae0af75b> in <module>()
# ----> 1 data_20150101 = date_sorted[date_sorted['date']>'2016-01-01']
#
# NameError: name 'date_sorted' is not defined

# %%
data_20150101 = data_20150101.reset_index().drop('index',axis=1)

# %%
data_20150101.shape
# Out:
# (950204, 22)

# %%
preprocessed_data = data_20150101.loc[:,['business_id','user_id','text']]

# %%
# The data for this analysis include restaurant reviews across two states Nevada and Arizona for the past 2.5 years

# %%
preprocessed_data.to_feather('./data/preprocessed_data')

# %% [markdown]
# Tokenization

# %%
import pandas as pd 
import numpy as np
import json
import re
from tqdm._tqdm_notebook import tqdm_notebook,
import spacy

# %%
preprocessed_data = pd.read_feather('preprocessed_data')

# %%
pd.read_feather('preprocessed_data').shape
# Out:
# (241221, 3)

# %%
nlp = spacy.load('en')

# %%
def clean_up_spacy(text):
    text_out = []
    doc= nlp(text)
    for token in doc:
        if token.is_stop == False and token.is_alpha and len(token)>2:
            lemma = token.lemma_
            text_out.append(lemma)
    return text_out

# %%
 
preprocessed_data['words'] = preprocessed_data['text'].progress_apply(lambda x: clean_up_spacy(x))
# Out:
# HBox(children=(IntProgress(value=0, description='my bar!', max=241221), HTML(value='')))

# %%
preprocessed_data.to_csv('./processed_data')

# %%
preprocessed_data = pd.read_csv('./processed_data')

# %%
preprocessed_data['doc_len'] = preprocessed_data['words'].map(len)

# %%
preprocessed_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,TfidfTransformer

# %%
# min_df is minimum number of documents that contain a term t
# max_features is maximum number of unique tokens (across documents) that we'd consider
# TfidfVectorizer preprocesses the descriptions using the tokenizer we defined above
vectorizer = TfidfVectorizer(min_df=10, max_features=10000, tokenizer=clean_up_spacy, ngram_range=(1, 2))
vz = vectorizer.fit_transform(list(preprocessed_data['text']))

# %%
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf.columns = ['tfidf']

# %%
tfidf.sort_values(by='tfidf',ascending=False)
# Out:
#                    tfidf
# ozzy            9.927737
# butterfly       9.011446
# yes yes         8.962656
# poké            8.962656
# taiyaki         8.950822
# shabu           8.939126
# maggiano        8.850178
# bouchon         8.818762
# halo halo       8.818762
# nora            8.808505
# jordan          8.798353
# koi             8.788303
# puerto          8.788303
# ikea            8.778352
# tim             8.778352
# white castle    8.768500
# blizzard        8.758744
# arepas          8.758744
# dosa            8.758744
# brazil          8.739513
# halo            8.730034
# roti            8.730034
# giada           8.720644
# ethiopian       8.720644
# gen             8.711342
# circus          8.702125
# port sub        8.702125
# korma           8.692993
# sinatra         8.683943
# palace station  8.683943
# ...                  ...
# recommend       3.224932
# taste           3.224051
# drink           3.191326
# look            3.185667
# want            3.110077
# menu            3.097167
# price           3.072295
# chicken         3.064914
# staff           3.036143
# amazing         3.029527
# definitely      2.990605
# nice            2.987726
# friendly        2.977521
# wait            2.969259
# delicious       2.854600
# restaurant      2.777943
# eat             2.771755
# love            2.727359
# go              2.696789
# get             2.684760
# try             2.565389
# like            2.453656
# time            2.293611
# order           2.239568
# come            2.238352
# great           2.100646
# service         2.057488
# place           1.920432
# good            1.701155
# food            1.681557
#
# [10000 rows x 1 columns]

# %%
import lda
from sklearn.feature_extraction.text import CountVectorizer
import logging
logging.getLogger("lda").setLevel(logging.WARNING)

# %%
cvectorizer = CountVectorizer(min_df=4, max_features=1000, tokenizer=clean_up_spacy, ngram_range=(1,2))
cvz = cvectorizer.fit_transform(list(preprocessed_data['text']))

# %%
n_topics = 5
n_iter = 500
lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)

# %%
n_top_words = 5
topic_summaries = []

topic_word = lda_model.topic_word_  # get the topic words
vocab = cvectorizer.get_feature_names()
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(' '.join(topic_words))
    print('Topic {}: {}'.format(i, ' + '.join(topic_words)))
# Out:
# Topic 0: great + place + food + good + love
# Topic 1: good + chicken + sauce + try + order
# Topic 2: good + place + like + come + time
# Topic 3: order + food + good + come + time
# Topic 4: taco + chip + die + mexican + und

# %% [markdown]
# LDA Trial 2

# %%
useless_words = tfidf.sort_values(by='tfidf',ascending=False).reset_index()
custom_stopwords = useless_words[:-(101):-1]['index'].values.tolist()

# %%
from spacy.lang.en.stop_words import STOP_WORDS
for sw in custom_stopwords:
    STOP_WORDS.add(sw)
    nlp.vocab[sw].is_stop = True

# %%
cvectorizer = CountVectorizer(min_df=4, max_features=10000, tokenizer=clean_up_spacy, ngram_range=(1,2))
cvz = cvectorizer.fit_transform(list(preprocessed_data['text']))

# %%
import _pickle as cPickle
with open('cvectorizer.pk', 'wb') as fin:
    cPickle.dump(cvectorizer, fin)

# %%
with open('tfidfvectorizer.pk', 'wb') as fin1:
    cPickle.dump(vectorizer, fin1)

# %%
n_topics = 50
n_iter = 1500
lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)
# Out:
# WARNING:lda:all zero row in document-term matrix found
# /home/ubuntu/src/anaconda3/envs/fastai/lib/python3.6/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):

# %%
with open('topicwords.csv','wb') as f:
    topic_word.tofile('topicwords')

# %%
n_top_words = 10
topic_summaries = []

topic_word = lda_model.topic_word_  # get the topic words
vocab = cvectorizer.get_feature_names()
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(' '.join(topic_words))
    print('Topic {}: {}'.format(i, ' + '.join(topic_words)))
# Out:
# Topic 0: item + offer + dining + restaurant + high + option + serve + make + include + thing
# Topic 1: onion + pepper + green + tomato + sweet + salt + serve + red + add + bit
# Topic 2: wing + pasta + italian + bread + garlic + order + meatball + good + spaghetti + olive
# Topic 3: portion + huge + size + large + half + plate + order + come + generous + share
# Topic 4: different + item + try + variety + dish + option + indian + choose + flavor + choice
# Topic 5: music + fun + drink + game + play + loud + live + watch + cool + bartender
# Topic 6: thank + attentive + care + take + come + helpful + good + wonderful + owner + make
# Topic 7: say + ask + walk + go + guy + lady + girl + tell + counter + rude
# Topic 8: breakfast + egg + pancake + toast + bacon + coffee + hash + french + brunch + potato
# Topic 9: wine + course + dining + dessert + glass + view + chef + beautiful + dish + appetizer
# Topic 10: hot + quick + fast + fish + dog + come + chip + clean + bite + stop
# Topic 11: coffee + tea + ice + drink + milk + sweet + boba + shop + latte + green
# Topic 12: let + go + away + blow + start + life + eat + thank + yes + mind
# Topic 13: clean + dirty + table + smell + bathroom + look + store + go + floor + hand
# Topic 14: taco + salsa + mexican + burrito + chip + bean + tortilla + asada + carne + carne asada
# Topic 15: strip + hotel + stay + parking + room + locate + casino + walk + mall + away
# Topic 16: cream + dessert + ice + chocolate + cake + ice cream + donut + sweet + cookie + crepe
# Topic 17: burger + fry + onion + shake + bun + bacon + ring + patty + order + onion ring
# Topic 18: taste + cold + dry + bad + order + money + disappointed + bland + eat + hard
# Topic 19: buffet + crab + seafood + good + selection + oyster + leg + station + dessert + crab leg
# Topic 20: party + group + birthday + large + friend + reservation + special + go + come + celebrate
# Topic 21: steak + cook + potato + order + medium + perfectly + filet + rib + rare + mash
# Topic 22: good + bit + high + price + expect + average + overall + decent + okay + probably
# Topic 23: come + ask + order + take + waitress + say + minute + tell + waiter + bring
# Topic 24: review + yelp + decide + find + look + glad + read + stop + see + want
# Topic 25: fry + sweet + waffle + potato + crispy + order + wing + sweet potato + get + tender
# Topic 26: busy + come + go + sunday + brunch + saturday + weekend + get + friday + late
# Topic 27: sandwich + bread + soup + sub + order + turkey + bagel + philly + grill + good
# Topic 28: pay + charge + extra + card + free + tip + go + money + bill + give
# Topic 29: bbq + rib + pork + brisket + short + mac + pull + short rib + tender + side
# Topic 30: order + call + get + delivery + pick + phone + say + tell + minute + wrong
# Topic 31: bowl + option + vegan + healthy + poke + veggie + vegetarian + rice + wrap + add
# Topic 32: crust + slice + thin + pie + topping + pizza + style + chicago + pepperoni + good
# Topic 33: shrimp + order + lobster + appetizer + cocktail + drink + seafood + entree + grill + calamari
# Topic 34: outside + patio + inside + seating + cool + outdoor + decor + sit + table + beautiful
# Topic 35: good + town + far + phoenix + place + live + gem + valley + hand + la
# Topic 36: rice + fry + chinese + beef + korean + fry rice + soup + order + egg + bbq
# Topic 37: thai + curry + spicy + pad + order + rice + spice + pad thai + dim + level
# Topic 38: time + close + open + go + couple + twice + try + week + late + hour
# Topic 39: manager + tell + say + owner + customer + rude + business + speak + ask + management
# Topic 40: beer + selection + free + gluten + gluten free + bartender + drink + wine + tap + option
# Topic 41: sushi + roll + fish + chef + tuna + salmon + good + ayce + rice + sashimi
# Topic 42: get + go + come + look + boyfriend + forward + try + eat + want + end
# Topic 43: star + water + give + reason + refill + drink + get + give star + waitress + glass
# Topic 44: price + family + highly + reasonable + recommend + friend + business + local + reasonably + owner
# Topic 45: seat + minute + wait + sit + walk + hostess + table + arrive + come + greet
# Topic 46: noodle + raman + pho + pork + soup + broth + beef + bowl + belly + spicy
# Topic 47: husband + kid + love + wife + old + family + son + daughter + go + year
# Topic 48: wait + line + minute + take + drive + min + go + get + slow + busy
# Topic 49: year + ago + go + week + come + gyro + greek + pita + month + good

# %%
def prepareLDAData():
    data = {
        'vocab': vocab,
        'doc_topic_dists': lda_model.doc_topic_,
        'doc_lengths': list(preprocessed_data['doc_len']),
        'term_frequency':cvectorizer.vocabulary_,
        'topic_term_dists': lda_model.components_
    } 
    return data

# %%
ldadata = prepareLDAData()

# %%
import pyLDAvis

# %%
pyLDAvis.enable_notebook()

# %%
prepared_data = pyLDAvis.prepare(**ldadata)
# Out:
# /home/ubuntu/src/anaconda3/envs/fastai/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]

# %%
pyLDAvis.save_html(prepared_data,'./pyldadavis.html')
